# %%
# Baseline Experiments: VLM и LLM Evaluation

"""В этом ноутбуке мы:
- Извлекаем ингредиенты через VLM (LLaVAVision)
- Генерируем рецепты через LLM (Mistral)
- Проверяем рецепты на диетические ограничения и уровни сложности
- Считаем latency, F1, Excess, токены
- Сохраняем результаты в отчёт """
# Out:
# 'В этом ноутбуке мы:\n- Извлекаем ингредиенты через VLM (LLaVAVision)\n- Генерируем рецепты через LLM (Mistral)\n- Проверяем рецепты на диетические ограничения и уровни сложности\n- Считаем latency, F1, Excess, токены\n- Сохраняем результаты в отчёт '

# %%
import os
import json
import time
import pandas as pd
from ml.models.baseline import LLaVAVision

# %%
def compute_precision_recall_f1(predicted, reference):
    predicted_set = set([p.lower() for p in predicted])
    reference_set = set([r.lower() for r in reference])

    tp = len(predicted_set & reference_set)
    fp = len(predicted_set - reference_set)
    fn = len(reference_set - predicted_set)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0.0

    return f1

def compute_excess(predicted, reference):
    reference_set = set([r.lower() for r in reference])
    predicted_set = set([p.lower() for p in predicted])
    excess = predicted_set - reference_set
    return len(excess) / len(predicted_set) if predicted_set else 0.0

# %%
def evaluate_vlm(eval_file="ml/tracing/vlm_eval_cases.json"):
    with open(eval_file, "r", encoding="utf-8") as f:
        eval_cases = json.load(f)

    vlm = LLaVAVision()
    results = []

    for idx, case in enumerate(eval_cases, start=1):
        image_path = case["image_path"]
        reference = case["reference_ingredients"]

        print(f"\n▶️ Тест #{idx}: {os.path.basename(image_path)}")

        start = time.time()
        pred = vlm.infer(image_path)
        latency = time.time() - start

        predicted = [ing["name"] if isinstance(ing, dict) else ing
                     for ing in pred.get("ingredients", [])]

        f1 = compute_precision_recall_f1(predicted, reference)
        excess = compute_excess(predicted, reference)

        results.append({
            "id": idx,
            "image": os.path.basename(image_path),
            "reference": reference,
            "predicted": predicted,
            "F1": round(f1, 3),
            "Excess": round(excess, 3),
            "Latency (сек)": round(latency, 3)
        })

    return results

# %%
results = evaluate_vlm()
# Out:
# ▶️ Тест #1: 1.jpg
#
# ▶️ Тест #2: 2.jpg
#
# ▶️ Тест #3: 3.jpg
#
# ▶️ Тест #4: 4.jpg
#
# ▶️ Тест #5: 5.jpg
#
# ▶️ Тест #6: 6.jpg
#
# ▶️ Тест #7: 7.jpg
#
# ▶️ Тест #8: 8.jpg
#
# ▶️ Тест #9: 9.jpg
#
# ▶️ Тест #10: 10.jpg

# %%
df = pd.DataFrame(results)
styled = (
    df.style
      .format({"F1": "{:.3f}", "Excess": "{:.3f}", "Latency (сек)": "{:.2f}"})
      .highlight_max(subset=["F1"], color="lightgreen")
      .highlight_min(subset=["Latency (сек)"], color="lightblue")
)
display(styled)

print("📊 Сводка по всем тестам")
print(f"Средний F1: {df['F1'].mean():.3f}")
print(f"Средний Excess: {df['Excess'].mean():.3f}")
print(f"Средний Latency: {df['Latency (сек)'].mean():.3f} сек")
# Out:
# <style type="text/css">
# #T_6d2ff_row0_col6 {
#   background-color: lightblue;
# }
# #T_6d2ff_row4_col4, #T_6d2ff_row5_col4, #T_6d2ff_row7_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6d2ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d2ff_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_6d2ff_level0_col1" class="col_heading level0 col1" >image</th>
#       <th id="T_6d2ff_level0_col2" class="col_heading level0 col2" >reference</th>
#       <th id="T_6d2ff_level0_col3" class="col_heading level0 col3" >predicted</th>
#       <th id="T_6d2ff_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6d2ff_level0_col5" class="col_heading level0 col5" >Excess</th>
#       <th id="T_6d2ff_level0_col6" class="col_heading level0 col6" >Latency (сек)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d2ff_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
import os
import json
import time
import re
import requests
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from ml.models.baseline import MistralText

# Загружаем ключи
load_dotenv()
MISTRAL_API_KEY = os.getenv("MISTRAL_API_KEY")
MISTRAL_URL = "https://api.mistral.ai/v1/chat/completions"
MISTRAL_MODEL = "mistral-small"

llm = MistralText()

# %%
def clean_mistral_output(output: str) -> str:
    if not isinstance(output, str):
        return ""
    clean = re.sub(r"^```(?:json)?", "", output.strip(), flags=re.IGNORECASE | re.MULTILINE)
    clean = re.sub(r"```$", "", clean.strip(), flags=re.MULTILINE)
    clean = re.sub(r"\n\s*-\s*\n", "\n", clean)
    clean = re.sub(r"^\s*-\s*{", "{", clean, flags=re.MULTILINE)
    clean = re.sub(r'[\x00-\x1f\x7f]', ' ', clean)
    end = clean.rfind("}")
    if end != -1:
        clean = clean[:end+1]
    return clean.strip()



def post_with_retries(url, headers, payload, timeout=60, max_retries=5, base_delay=0.8):
    """Ретраи с экспоненциальной задержкой и джиттером для 429/5xx ошибок."""
    last_resp = None
    for attempt in range(1, max_retries + 1):
        resp = requests.post(url, headers=headers, json=payload, timeout=timeout)
        last_resp = resp

        if resp.status_code == 200:
            return resp

        retry_after = resp.headers.get("Retry-After")
        if resp.status_code in (429, 500, 502, 503, 504):
            if attempt == max_retries:
                break
            if retry_after:
                try:
                    delay = float(retry_after)
                except Exception:
                    delay = base_delay * (2 ** (attempt - 1)) + random.uniform(0, 0.5)
            else:
                delay = base_delay * (2 ** (attempt - 1)) + random.uniform(0, 0.5)
            time.sleep(delay)
            continue
        break
    return last_resp

# %%
def check_with_mistral(
    recipes,
    dietary,
    preferred_difficulty=None,   # 'легко' / 'средне' / 'сложно' или None/нет
    preferred_time=None,         # 'быстро' / 'средне' / 'долго' или None/нет
    preferred_calories=None      # 'низкокалорийное' / 'среднекалорийное' / 'высококалорийное' или None/нет
):
    """
    Проверяет:
    - dietary_ok: нет запрещённых ингредиентов (учёт производных).
    - difficulty_ok: если задано предпочтение, ВСЕ рецепты имеют указанную сложность.
    - time_ok: если задано предпочтение, ВСЕ рецепты имеют указанное время.
    - calories_ok: если задано предпочтение, ВСЕ рецепты имеют указанную калорийность.
    Если предпочтение не задано (None/нет) — критерий считается true.
    """
    headers = {
        "Authorization": f"Bearer {MISTRAL_API_KEY}",
        "Content-Type": "application/json"
    }

    # Нормализуем 'нет' → None для простоты логики
    def norm(x):
        x = (x or "").strip().lower()
        return None if x in ("", "нет", "none", "null") else x

    preferred_difficulty = norm(preferred_difficulty)
    preferred_time = norm(preferred_time)
    preferred_calories = norm(preferred_calories)

    prompt = (
        "Ты проверяющий ассистент. Верни строго валидный JSON без Markdown.\n\n"
        "Задача: проверить список рецептов на соответствие диете и указанным предпочтениям.\n"
        "Если предпочтение не задано, соответствующий флаг считаем true.\n\n"
        "Категории:\n"
        " - Сложность: легко / средне / сложно\n"
        " - Время готовки: быстро / средне / долго\n"
        " - Калорийность: низкокалорийное / среднекалорийное / высококалорийное\n\n"
        f"Рецепты (JSON):\n{json.dumps(recipes, ensure_ascii=False, indent=2)}\n\n"
        f"Диетические ограничения: {dietary or 'нет'}\n"
        f"Предпочитаемая сложность: {preferred_difficulty or 'нет'}\n"
        f"Предпочитаемое время: {preferred_time or 'нет'}\n"
        f"Предпочитаемая калорийность: {preferred_calories or 'нет'}\n\n"
        "Проверь:\n"
        "1) Нет ли запрещённых ингредиентов или их производных (например, 'лактоза' запрещает молочные продукты).\n"
        "2) Если задана предпочитаемая сложность — ВСЕ рецепты должны иметь ровно эту сложность.\n"
        "3) Если задано предпочитаемое время — ВСЕ рецепты должны иметь ровно это время.\n"
        "4) Если задана предпочитаемая калорийность — ВСЕ рецепты должны иметь ровно эту калорийность.\n\n"
        "Ответь ТОЛЬКО JSON следующей формы:\n"
        "{\n"
        '  "dietary_ok": true,\n'
        '  "difficulty_ok": true,\n'
        '  "time_ok": true,\n'
        '  "calories_ok": true\n'
        "}\n"
    )

    payload = {
        "model": MISTRAL_MODEL,
        "messages": [
            {"role": "system", "content": "Ты проверяющий ассистент. Возвращай только JSON."},
            {"role": "user", "content": prompt}
        ],
        "temperature": 0.1,
        "max_tokens": 256,
    }

    resp = requests.post(MISTRAL_URL, headers=headers, json=payload, timeout=60)
    if resp.status_code != 200:
        return {"error": f"Mistral API error: {resp.status_code}"}

    data = resp.json()
    content = (
        data.get("choices", [{}])[0]
        .get("message", {})
        .get("content", "")
        .strip()
    ) or data.get("choices", [{}])[0].get("text", "").strip()

    if not content:
        return {"error": "Empty response"}

    cleaned = clean_mistral_output(content)
    try:
        parsed = json.loads(cleaned)
    except Exception as e:
        return {"error": f"Invalid JSON: {e}", "raw_output": content, "cleaned": cleaned}

    usage = data.get("usage", {}) or {}
    return {
        "dietary_ok": bool(parsed.get("dietary_ok", False)),
        "difficulty_ok": bool(parsed.get("difficulty_ok", False)),
        "time_ok": bool(parsed.get("time_ok", False)),
        "calories_ok": bool(parsed.get("calories_ok", False)),
        "usage": usage
    }

# %%
async def run_tests(tests_path="ml/tracing/test_recipes.json", return_df=True):
    with open(tests_path, "r", encoding="utf-8") as f:
        test_cases = json.load(f)

    total = len(test_cases)
    passed_all = passed_diet = passed_diff = passed_time = passed_calories = 0
    all_results = []

    for idx, case in enumerate(test_cases, start=1):
        print(f"\n▶️ Тест {idx}/{total}: ингредиенты={case['ingredients']}, диета={case.get('dietary', 'нет')}, "
              f"сложность={case.get('preferred_difficulty','нет')}, "
              f"время={case.get('preferred_cooking_time','нет')}, "
              f"калорийность={case.get('preferred_calorie_level','нет')}")

        start = time.time()
        recipes = await llm.generate_recipe(
            case["ingredients"],
            dietary=case.get("dietary", "нет"),
            feedback=case.get("user_feedback", "нет"),
            preferred_difficulty=case.get("preferred_difficulty", "нет"),
            preferred_cooking_time=case.get("preferred_cooking_time", "нет"),
            preferred_calorie_level=case.get("preferred_calorie_level", "нет")
        )
        gen_latency = round(time.time() - start, 3)

        if isinstance(recipes, dict) and "error" in recipes:
            print("  ❌ Ошибка генерации")
            all_results.append({
                "id": idx,
                "ingredients": case["ingredients"],
                "dietary": case.get("dietary", "нет"),
                "preferred_difficulty": case.get("preferred_difficulty", "нет"),
                "preferred_time": case.get("preferred_cooking_time", "нет"),
                "preferred_calories": case.get("preferred_calorie_level", "нет"),
                "dietary_ok": None,
                "difficulty_ok": None,
                "time_ok": None,
                "calories_ok": None,
                "gen_latency": gen_latency,
                "total_tokens": None,
                "error": recipes.get("error"),
                "recipes": []
            })
            continue

        if recipes is None:
            recipes = []
        elif isinstance(recipes, dict):
            recipes = [recipes]

        check_result = check_with_mistral(
            recipes,
            case.get("dietary", "нет"),
            case.get("preferred_difficulty", "нет"),
            case.get("preferred_cooking_time", "нет"),
            case.get("preferred_calorie_level", "нет")
        )

        if "error" in check_result:
            print(f"  ❌ Ошибка проверки: {check_result}")
            all_results.append({
                "id": idx,
                "ingredients": case["ingredients"],
                "dietary": case.get("dietary", "нет"),
                "preferred_difficulty": case.get("preferred_difficulty", "нет"),
                "preferred_time": case.get("preferred_cooking_time", "нет"),
                "preferred_calories": case.get("preferred_calorie_level", "нет"),
                "dietary_ok": None,
                "difficulty_ok": None,
                "time_ok": None,
                "calories_ok": None,
                "gen_latency": gen_latency,
                "total_tokens": None,
                "error": check_result.get("error"),
                "recipes": recipes
            })
            continue

        dietary_ok = "OK" if check_result.get("dietary_ok", False) else "FAIL"
        difficulty_ok = "OK" if check_result.get("difficulty_ok", False) else "FAIL"
        time_ok = "OK" if check_result.get("time_ok", False) else "FAIL"
        calories_ok = "OK" if check_result.get("calories_ok", False) else "FAIL"
        usage = check_result.get("usage", {}) or {}

        if dietary_ok == "OK": passed_diet += 1
        if difficulty_ok == "OK": passed_diff += 1
        if time_ok == "OK": passed_time += 1
        if calories_ok == "OK": passed_calories += 1
        if all(v == "OK" for v in [dietary_ok, difficulty_ok, time_ok, calories_ok]):
            passed_all += 1

        print(f"  Диета: {dietary_ok}, Сложность: {difficulty_ok}, Время: {time_ok}, Калории: {calories_ok}")

        all_results.append({
            "id": idx,
            "ingredients": case["ingredients"],
            "dietary": case.get("dietary", "нет"),
            "preferred_difficulty": case.get("preferred_difficulty", "нет"),
            "preferred_time": case.get("preferred_cooking_time", "нет"),
            "preferred_calories": case.get("preferred_calorie_level", "нет"),
            "dietary_ok": dietary_ok,
            "difficulty_ok": difficulty_ok,
            "time_ok": time_ok,
            "calories_ok": calories_ok,
            "gen_latency": gen_latency,
            "total_tokens": usage.get("total_tokens"),
            "error": None,
            "recipes": recipes
        })

    print(f"\n📊 Итог по {total} тестам:")
    print(f"✅ Диета: {passed_diet}/{total}")
    print(f"✅ Сложность: {passed_diff}/{total}")
    print(f"✅ Время: {passed_time}/{total}")
    print(f"✅ Калорийность: {passed_calories}/{total}")
    print(f"✅ Все условия: {passed_all}/{total}")

    df = pd.DataFrame(all_results)
    return df if return_df else all_results

# %%
df = await run_tests()

# Заменяем None на NaN для форматирования
df["gen_latency"] = df["gen_latency"].replace({None: np.nan})
df["total_tokens"] = df["total_tokens"].replace({None: np.nan})

styled = (
    df.drop(columns=["recipes"], errors="ignore")
    .style
    .format({
        "gen_latency": lambda x: f"{x:.2f}" if pd.notnull(x) else "",
        "total_tokens": lambda x: f"{int(x)}" if pd.notnull(x) else ""
    })
    .highlight_min(subset=["gen_latency"], color="lightblue")
    .highlight_max(subset=["gen_latency"], color="lightcoral")
    .map(
        lambda x: "background-color: #d4edda" if x == "OK" else (
            "background-color: #f8d7da" if x == "FAIL" else ""
        ),
        subset=["dietary_ok", "difficulty_ok", "time_ok", "calories_ok"]
    )
)

display(styled)

print("📈 Средняя генерация (сек.):", round(df["gen_latency"].dropna().mean(), 2))
print("📊 Средний total_tokens:", round(df["total_tokens"].dropna().mean(), 1))

total = len(df)
passed_diet = df["dietary_ok"].eq("OK").sum()
passed_diff = df["difficulty_ok"].eq("OK").sum()
passed_time = df["time_ok"].eq("OK").sum()
passed_calories = df["calories_ok"].eq("OK").sum()
passed_all = df[["dietary_ok", "difficulty_ok", "time_ok", "calories_ok"]].apply(
    lambda row: all(val == "OK" for val in row), axis=1
).sum()

print(f"\n📋 Итог по {total} тестам:")
print(f"✅ Диета: {passed_diet}/{total}")
print(f"✅ Сложность: {passed_diff}/{total}")
print(f"✅ Время: {passed_time}/{total}")
print(f"✅ Калорийность: {passed_calories}/{total}")
print(f"✅ Все условия: {passed_all}/{total}")
# Out:
# ▶️ Тест 1/10: ингредиенты=[{'name': 'картофель'}, {'name': 'молоко'}, {'name': 'курица'}], диета=лактоза, сложность=средне, время=средне, калорийность=среднекалорийное
#   Диета: OK, Сложность: OK, Время: OK, Калории: OK
#
# ▶️ Тест 2/10: ингредиенты=[{'name': 'куриная грудка'}, {'name': 'рис'}, {'name': 'брокколи'}], диета=нет, сложность=легко, время=быстро, калорийность=низкокалорийное
#   Диета: OK, Сложность: OK, Время: OK, Калории: OK
#
# ▶️ Тест 3/10: ингредиенты=[{'name': 'макароны'}, {'name': 'фарш'}, {'name': 'чеснок'}], диета=нет, сложность=средне, время=средне, калорийность=среднекалорийное
#   Диета: OK, Сложность: OK, Время: OK, Калории: OK
#
# ▶️ Тест 4/10: ингредиенты=[{'name': 'лосось'}, {'name': 'огурцы'}, {'name': 'помидоры'}], диета=рыба, сложность=сложно, время=долго, калорийность=высококалорийное
#   Диета: OK, Сложность: OK, Время: OK, Калории: OK
#
# ...

# %%
rows = []
for _, row in df.iterrows():
    for rec in (row.get("recipes") or []):
        name = rec.get("name", "")
        ingredients = rec.get("ingredients", [])
        if isinstance(ingredients, dict):
            ingredients_list = [f"{k}: {v}" for k, v in ingredients.items()]
        else:
            ingredients_list = [i if isinstance(i, str) else i.get("name", "") for i in ingredients]
        rows.append({
            "id": row["id"],
            "dietary": row["dietary"],
            "recipe_name": name,
            "ingredients": ", ".join(ingredients_list),
            "difficulty": rec.get("difficulty", "")
        })

df_recipes = pd.DataFrame(rows)
display(df_recipes)
# Out:
#     id  dietary                                        recipe_name  \
# 0    1  лактоза      Картофельное пюре на воде с куриной подливкой
# 1    1  лактоза            Запечённая курица с картофелем в фольге
# 2    1  лактоза              Куриный бульон с картофелем (быстрый)
# 3    2      нет                  Лёгкий салат с курицей и брокколи
# 4    2      нет             Курица с рисом и брокколи на сковороде
# 5    2      нет   Запечённая курица с рисом и брокколи в горшочках
# 6    3      нет        Чесночный соус с макаронами (аглио э олlio)
# 7    3      нет                          Простые макароны с фаршем
# 8    3      нет  Запечённые макароны с фаршем и чесночной корочкой
# 9    4     рыба  Лёгкий салат из огурцов и помидоров с лимонной...
# 10   4     рыба              Тушёные помидоры с огурцами и травами
# 11   4     рыба  Фаршированные помидоры с огурцами и овощной на...
# 12   5      нет                     Лёгкий салат с курицей и нутом
# ...
